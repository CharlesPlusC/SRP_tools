# %%
# !pip install ipydatawidgets

# %%
# !jupyter nbextension enable --py --sys-prefix pythreejs
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Traceback (most recent call last):
#   File "/Users/charlesc/opt/anaconda3/bin/jupyter-nbextension", line 8, in <module>
#     sys.exit(main())
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/traitlets/config/application.py", line 846, in launch_instance
#     app.start()
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 972, in start
#     super().start()
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/jupyter_core/application.py", line 258, in start
#     self.subapp.start()
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 882, in start
#     self.toggle_nbextension_python(self.extra_args[0])
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 855, in toggle_nbextension_python
#     return toggle(module,
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 470, in enable_nbextension_python
#     return _set_nbextension_state_python(True, module, user, sys_prefix,
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 368, in _set_nbextension_state_python
#     m, nbexts = _get_nbextension_metadata(module)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/notebook/nbextensions.py", line 1107, in _get_nbextension_metadata
#     m = import_item(module)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/traitlets/utils/importstring.py", line 38, in import_item
#     return __import__(parts[0])
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/pythreejs/__init__.py", line 6, in <module>
#     from .pythreejs import *
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/pythreejs/pythreejs.py", line 20, in <module>
#     from .core.BufferAttribute import BufferAttribute
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/pythreejs/core/BufferAttribute.py", line 4, in <module>
#     from .BufferAttribute_autogen import BufferAttribute as BaseBufferAttribute
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/pythreejs/core/BufferAttribute_autogen.py", line 13, in <module>
#     from ..traits import *
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/pythreejs/traits.py", line 18, in <module>
#     from ipydatawidgets import DataUnion, NDArrayWidget, shape_constraints
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/__init__.py", line 7, in <module>
#     from .ndarray import *
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/__init__.py", line 7, in <module>
#     from .media import DataImage
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/media.py", line 17, in <module>
#     class DataImage(DataWidget, DOMWidget):
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 807, in __init__
#     cls.setup_class(classdict)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 830, in setup_class
#     super(MetaHasTraits, cls).setup_class(classdict)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py", line 822, in setup_class
#     v.subclass_init(cls)
#   File "/Users/charlesc/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/union.py", line 59, in subclass_init
#     cls._instance_inits.append(self.instance_init)
# AttributeError: type object 'DataImage' has no attribute '_instance_inits'
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
import numpy as np
from pythreejs import Renderer, Scene, PerspectiveCamera, Mesh, BoxGeometry, SphereGeometry, CylinderGeometry, ConeGeometry, PlaneGeometry, MeshStandardMaterial, DirectionalLight, OrbitControls
from IPython.display import display

class GeometricPrimitive:
    def __init__(self, geometry, position, rotation):
        self.geometry = geometry
        self.position = position
        self.rotation = rotation


def create_mesh(primitive, material):
    mesh = Mesh(geometry=primitive.geometry, material=material)
    mesh.position = primitive.position
    mesh.rotation = primitive.rotation
    return mesh

def visualize_primitives(primitives):
    camera = PerspectiveCamera(position=[3, 3, 3], aspect=1.0)
    controls = OrbitControls(controlling=camera)
    light = DirectionalLight(position=[10, 10, 10])

    scene = Scene()
    scene.add(camera)
    scene.add(light)

    material = MeshStandardMaterial(color='red')

    for primitive in primitives:
        mesh = create_mesh(primitive, material)
        scene.add(mesh)

    renderer = Renderer(scene, camera, [controls], width=800, height=600)

    return renderer

def main():
    box = GeometricPrimitive(BoxGeometry(width=1, height=1, depth=1), position=[-1, 0, 0], rotation=[0, 0, 0, 0])
    sphere = GeometricPrimitive(SphereGeometry(radius=0.5), position=[1, 0, 0], rotation=[0, 0, 0])
    cylinder = GeometricPrimitive(CylinderGeometry(radiusTop=0.3, radiusBottom=0.5, height=1), position=[0, 1, 0], rotation=[0, 0, 0])
    cone = GeometricPrimitive(ConeGeometry(radius=0.5, height=1), position=[0, -1, 0], rotation=[0, 0, 0])
    plane = GeometricPrimitive(PlaneGeometry(width=5, height=5), position=[0, -1.5, 0], rotation=[-np.pi / 2, 0, 0])

    primitives = [box, sphere, cylinder, cone, plane]

    renderer = visualize_primitives(primitives)
    display(renderer)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/nh/9y501_nj2x56h2t3ch9_05f40000gn/T/ipykernel_27876/2151799611.py in <module>
#       1 import numpy as np
# ----> 2 from pythreejs import Renderer, Scene, PerspectiveCamera, Mesh, BoxGeometry, SphereGeometry, CylinderGeometry, ConeGeometry, PlaneGeometry, MeshStandardMaterial, DirectionalLight, OrbitControls
#       3 from IPython.display import display
#       4
#       5 class GeometricPrimitive:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pythreejs/__init__.py in <module>
#       4
#       5 from .enums import *
# ----> 6 from .pythreejs import *
#       7 from .traits import *
#       8 from ._example_helper import *
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pythreejs/pythreejs.py in <module>
#      18
#      19
# ---> 20 from .core.BufferAttribute import BufferAttribute
#      21 from .core.Geometry import Geometry
#      22 from .core.BufferGeometry import BufferGeometry
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pythreejs/core/BufferAttribute.py in <module>
#       2
#       3 from .._base.Three import ThreeWidget
# ----> 4 from .BufferAttribute_autogen import BufferAttribute as BaseBufferAttribute
#       5
#       6
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pythreejs/core/BufferAttribute_autogen.py in <module>
#      11 from .._base.uniforms import uniforms_serialization
#      12 from ..enums import *
# ---> 13 from ..traits import *
#      14
#      15 from .._base.Three import ThreeWidget
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pythreejs/traits.py in <module>
#      16 from ipywidgets import widget_serialization
#      17
# ---> 18 from ipydatawidgets import DataUnion, NDArrayWidget, shape_constraints
#      19
#      20 import numpy as np
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/__init__.py in <module>
#       5 # Distributed under the terms of the Modified BSD License.
#       6
# ----> 7 from .ndarray import *
#       8 from .widgets import DataWidget
#       9 from ._version import __version__, version_info
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/__init__.py in <module>
#       5 # Distributed under the terms of the Modified BSD License.
#       6
# ----> 7 from .media import DataImage
#       8 from .serializers import array_serialization, data_union_serialization
#       9 from .traits import NDArray, shape_constraints
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/media.py in <module>
#      15
#      16
# ---> 17 class DataImage(DataWidget, DOMWidget):
#      18     """A data-widgets based Image widget.
#      19     """
#
# ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in __init__(cls, name, bases, classdict)
#     805         """Finish initializing the HasDescriptors class."""
#     806         super(MetaHasDescriptors, cls).__init__(name, bases, classdict)
# --> 807         cls.setup_class(classdict)
#     808
#     809     def setup_class(cls, classdict):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in setup_class(cls, classdict)
#     828     def setup_class(cls, classdict):
#     829         cls._trait_default_generators = {}
# --> 830         super(MetaHasTraits, cls).setup_class(classdict)
#     831
#     832
#
# ~/opt/anaconda3/lib/python3.9/site-packages/traitlets/traitlets.py in setup_class(cls, classdict)
#     820         for k, v in getmembers(cls):
#     821             if isinstance(v, BaseDescriptor):
# --> 822                 v.subclass_init(cls)
#     823
#     824
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipydatawidgets/ndarray/union.py in subclass_init(self, cls)
#      57
#      58     def subclass_init(self, cls):
# ---> 59         cls._instance_inits.append(self.instance_init)
#      60         return super().subclass_init(cls)
#      61
#
# AttributeError: type object 'DataImage' has no attribute '_instance_inits'

# %%
main()

# %%
conda update ipywidgets
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::holoviews==1.15.0=py39hecd8cb5_0
#   - defaults/osx-64::jupyterlab==3.4.4=py39hecd8cb5_0
#   - defaults/osx-64::anaconda==2022.10=py39_0
#   - defaults/osx-64::hvplot==0.8.0=py39hecd8cb5_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py39hecd8cb5_1
#   - defaults/osx-64::jupyter==1.0.0=py39hecd8cb5_8
#   - defaults/noarch::ipywidgets==7.6.5=pyhd3eb1b0_1
#   - defaults/osx-64::widgetsnbextension==3.5.2=py39hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/charlesc/opt/anaconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2023.03  |           py39_0          67 KB
#     anaconda-custom            |           py39_1           4 KB
#     anaconda-client-1.11.1     |   py39hecd8cb5_0         141 KB
#     arrow-1.2.3                |   py39hecd8cb5_1         157 KB
#     astroid-2.14.2             |   py39hecd8cb5_0         405 KB
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     attrs-22.1.0               |   py39hecd8cb5_0          84 KB
#     babel-2.11.0               |   py39hecd8cb5_0         6.8 MB
#     blas-1.0                   |         openblas          45 KB
#     blosc-1.21.3               |       hcec6c5f_0          61 KB
#     c-ares-1.19.0              |       h6c40b1e_0         105 KB
#     certifi-2022.12.7          |   py39hecd8cb5_0         151 KB
#     cffi-1.15.1                |   py39h6c40b1e_3         235 KB
#     colorama-0.4.6             |   py39hecd8cb5_0          32 KB
#     colorcet-3.0.1             |   py39hecd8cb5_0         1.9 MB
#     comm-0.1.2                 |   py39hecd8cb5_0          14 KB
#     conda-package-handling-2.0.2|   py39hecd8cb5_0         268 KB
#     conda-package-streaming-0.7.0|   py39hecd8cb5_0          28 KB
#     conda-repo-cli-1.0.27      |   py39hecd8cb5_0         117 KB
#     contourpy-1.0.5            |   py39haf03e11_0         205 KB
#     cryptography-39.0.1        |   py39hf6deb26_0         1.0 MB
#     curl-7.88.1                |       h6c40b1e_0          84 KB
#     cytoolz-0.12.0             |   py39hca72f7f_0         331 KB
#     dask-2022.2.1              |     pyhd3eb1b0_0           5 KB
#     dask-core-2022.2.1         |     pyhd3eb1b0_0         747 KB
#     datashader-0.14.4          |   py39hecd8cb5_0        16.7 MB
#     dill-0.3.6                 |   py39hecd8cb5_0         167 KB
#     distributed-2022.2.1       |     pyhd3eb1b0_0         659 KB
#     docstring-to-markdown-0.11 |   py39hecd8cb5_0          32 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     filelock-3.9.0             |   py39hecd8cb5_0          19 KB
#     flake8-6.0.0               |   py39hecd8cb5_0         156 KB
#     flit-core-3.8.0            |   py39hecd8cb5_0          87 KB
#     freetype-2.12.1            |       hd8bbffd_0         592 KB
#     fsspec-2023.3.0            |   py39hecd8cb5_0         232 KB
#     future-0.18.3              |   py39hecd8cb5_0         677 KB
#     gensim-4.3.0               |   py39hcec6c5f_0        21.9 MB
#     geos-3.8.0                 |       hb1e8313_0         815 KB
#     giflib-5.2.1               |       h6c40b1e_3          81 KB
#     glib-2.69.1                |       hfff2838_2         3.0 MB
#     greenlet-2.0.1             |   py39hcec6c5f_0         184 KB
#     gst-plugins-base-1.14.1    |       hcec6c5f_1         1.7 MB
#     gstreamer-1.14.1           |       h6c40b1e_1         1.7 MB
#     huggingface_hub-0.10.1     |   py39hecd8cb5_0         210 KB
#     idna-3.4                   |   py39hecd8cb5_0          96 KB
#     imagecodecs-2021.8.26      |   py39h8a96914_2         6.0 MB
#     imageio-2.26.0             |   py39hecd8cb5_0         3.3 MB
#     imbalanced-learn-0.10.1    |   py39hecd8cb5_0         281 KB
#     importlib-metadata-6.0.0   |   py39hecd8cb5_0          40 KB
#     importlib_metadata-6.0.0   |       hd3eb1b0_0           8 KB
#     importlib_resources-5.2.0  |     pyhd3eb1b0_1          21 KB
#     intake-0.6.8               |   py39hecd8cb5_0         210 KB
#     ipykernel-6.19.2           |   py39h01d92e1_0         215 KB
#     ipython-8.10.0             |   py39hecd8cb5_0         1.1 MB
#     jaraco.classes-3.2.1       |     pyhd3eb1b0_0           9 KB
#     joblib-1.1.1               |   py39hecd8cb5_0         384 KB
#     jpeg-9e                    |       h6c40b1e_1         252 KB
#     jsonschema-4.17.3          |   py39hecd8cb5_0         140 KB
#     jupyter_client-7.4.9       |   py39hecd8cb5_0         212 KB
#     jupyter_console-6.6.2      |   py39hecd8cb5_0          45 KB
#     jupyter_core-5.2.0         |   py39hecd8cb5_0          91 KB
#     jupyter_server-1.23.4      |   py39hecd8cb5_0         387 KB
#     jupyterlab_widgets-3.0.5   |   py39hecd8cb5_0         180 KB
#     keyring-23.13.1            |   py39hecd8cb5_0          66 KB
#     kiwisolver-1.4.4           |   py39hcec6c5f_0          63 KB
#     krb5-1.19.4                |       hdba6334_0         1.2 MB
#     libarchive-3.6.2           |       h65c5294_0         777 KB
#     libcurl-7.88.1             |       ha585b31_0         348 KB
#     libdeflate-1.17            |       hb664fd8_0          72 KB
#     libedit-3.1.20221030       |       h6c40b1e_0         155 KB
#     libffi-3.4.2               |       hecd8cb5_6         127 KB
#     libgfortran-5.0.0          |11_3_0_hecd8cb5_28         142 KB
#     libgfortran5-11.3.0        |      h9dfd629_28         1.4 MB
#     liblief-0.12.3             |       hcec6c5f_0         1.8 MB
#     libllvm11-11.1.0           |       h46f1229_6        17.7 MB
#     libllvm14-14.0.6           |       h91fad77_1        24.1 MB
#     libopenblas-0.3.21         |       h54e7dc3_0         4.9 MB
#     libpng-1.6.39              |       h6c40b1e_0         290 KB
#     libprotobuf-3.20.3         |       hfff2838_0         2.0 MB
#     libtiff-4.5.0              |       hcec6c5f_2         498 KB
#     libuv-1.44.2               |       h6c40b1e_0         388 KB
#     libwebp-1.2.4              |       hf6ce154_1          83 KB
#     libwebp-base-1.2.4         |       h6c40b1e_1         367 KB
#     llvmlite-0.39.1            |   py39h8346a28_0         241 KB
#     lz4-c-1.9.4                |       hcec6c5f_0         167 KB
#     markdown-3.4.1             |   py39hecd8cb5_0         130 KB
#     matplotlib-3.7.1           |   py39hecd8cb5_0           9 KB
#     matplotlib-base-3.7.1      |   py39hda11e5a_0         6.7 MB
#     more-itertools-8.12.0      |     pyhd3eb1b0_0          49 KB
#     nbclassic-0.5.2            |   py39hecd8cb5_0         6.3 MB
#     nbformat-5.7.0             |   py39hecd8cb5_0         135 KB
#     ncurses-6.4                |       hcec6c5f_0        1018 KB
#     nest-asyncio-1.5.6         |   py39hecd8cb5_0          16 KB
#     networkx-2.8.4             |   py39hecd8cb5_1         2.6 MB
#     ninja-1.10.2               |       hecd8cb5_5           9 KB
#     ninja-base-1.10.2          |       haf03e11_5         118 KB
#     notebook-6.5.2             |   py39hecd8cb5_0         507 KB
#     notebook-shim-0.2.2        |   py39hecd8cb5_0          23 KB
#     numba-0.56.4               |   py39h07fba90_0         4.0 MB
#     numexpr-2.8.4              |   py39h57a7bef_0         128 KB
#     numpy-1.23.5               |   py39h57a7bef_0          11 KB
#     numpy-base-1.23.5          |   py39hc93c6d9_0         6.3 MB
#     numpydoc-1.5.0             |   py39hecd8cb5_0          93 KB
#     openssl-1.1.1t             |       hca72f7f_0         3.3 MB
#     packaging-23.0             |   py39hecd8cb5_0          71 KB
#     panel-0.14.3               |   py39hecd8cb5_0        12.6 MB
#     param-1.12.3               |   py39hecd8cb5_0         149 KB
#     pathspec-0.10.3            |   py39hecd8cb5_0          51 KB
#     patsy-0.5.3                |   py39hecd8cb5_0         283 KB
#     pillow-9.4.0               |   py39hcec6c5f_0         691 KB
#     pip-23.0.1                 |   py39hecd8cb5_0         2.5 MB
#     pkginfo-1.9.6              |   py39hecd8cb5_0          51 KB
#     pooch-1.4.0                |     pyhd3eb1b0_0          41 KB
#     proj-8.2.1                 |       hd69def0_0         2.5 MB
#     prompt-toolkit-3.0.36      |   py39hecd8cb5_0         575 KB
#     prompt_toolkit-3.0.36      |       hd3eb1b0_0           5 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     py-lief-0.12.3             |   py39hcec6c5f_0         1.1 MB
#     pycodestyle-2.10.0         |   py39hecd8cb5_0          69 KB
#     pycosat-0.6.4              |   py39hca72f7f_0          90 KB
#     pyct-0.5.0                 |   py39hecd8cb5_0          32 KB
#     pycurl-7.45.2              |   py39hdb2fb19_0         130 KB
#     pydocstyle-6.3.0           |   py39hecd8cb5_0          71 KB
#     pyflakes-3.0.1             |   py39hecd8cb5_0         119 KB
#     pylint-2.16.2              |   py39hecd8cb5_0         734 KB
#     pylint-venv-2.3.0          |   py39hecd8cb5_0          12 KB
#     pyobjc-core-9.0            |   py39h9205ec4_1         419 KB
#     pyobjc-framework-cocoa-9.0 |   py39h9205ec4_0         336 KB
#     pyobjc-framework-coreservices-9.0|   py39h46256e1_0          40 KB
#     pyobjc-framework-fsevents-9.0|   py39hecd8cb5_0          15 KB
#     pyopenssl-23.0.0           |   py39hecd8cb5_0          98 KB
#     pyproj-3.4.1               |   py39hf797ea4_0         412 KB
#     pyshp-2.1.3                |     pyhd3eb1b0_0          37 KB
#     pytables-3.7.0             |   py39h59775c6_1         1.6 MB
#     python-3.9.16              |       h218abb5_2        12.7 MB
#     python-lsp-server-1.7.1    |   py39hecd8cb5_0         107 KB
#     python-snappy-0.6.1        |   py39hcec6c5f_0          30 KB
#     pytoolconfig-1.2.5         |   py39hecd8cb5_1          33 KB
#     pytorch-1.12.1             |cpu_py39h64f2f56_1        45.1 MB
#     pytz-2022.7                |   py39hecd8cb5_0         210 KB
#     pywavelets-1.4.1           |   py39h6c40b1e_0         3.6 MB
#     pyyaml-6.0                 |   py39h6c40b1e_1         172 KB
#     qstylizer-0.2.2            |   py39hecd8cb5_0          31 KB
#     qtawesome-1.2.2            |   py39hecd8cb5_0         1.6 MB
#     qtconsole-5.4.0            |   py39hecd8cb5_0         193 KB
#     readline-8.2               |       hca72f7f_0         328 KB
#     requests-2.28.1            |   py39hecd8cb5_1          99 KB
#     rope-1.7.0                 |   py39hecd8cb5_0         441 KB
#     rtree-1.0.1                |   py39hecd8cb5_0          50 KB
#     scikit-image-0.19.3        |   py39hcec6c5f_1         9.9 MB
#     scikit-learn-1.2.1         |   py39hcec6c5f_0         7.0 MB
#     scipy-1.10.0               |   py39h9034365_1        21.0 MB
#     scrapy-2.8.0               |   py39hecd8cb5_0         406 KB
#     seaborn-0.12.2             |   py39hecd8cb5_0         483 KB
#     setuptools-65.6.3          |   py39hecd8cb5_0         1.1 MB
#     soupsieve-2.3.2.post1      |   py39hecd8cb5_0          66 KB
#     spyder-5.4.2               |   py39hecd8cb5_0        10.4 MB
#     spyder-kernels-2.4.2       |   py39hecd8cb5_0         152 KB
#     sqlite-3.41.1              |       h6c40b1e_0         1.2 MB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     statsmodels-0.13.5         |   py39hacda100_1         9.8 MB
#     sympy-1.11.1               |   py39hecd8cb5_0        11.7 MB
#     tbb-2021.7.0               |       ha357a0b_0         172 KB
#     tbb4py-2021.7.0            |   py39ha357a0b_0          55 KB
#     terminado-0.17.1           |   py39hecd8cb5_0          33 KB
#     tinycss2-1.2.1             |   py39hecd8cb5_0          40 KB
#     tokenizers-0.11.4          |   py39h8776b5c_1         2.7 MB
#     toolz-0.12.0               |   py39hecd8cb5_0         106 KB
#     tornado-6.2                |   py39hca72f7f_0         599 KB
#     traitlets-5.7.1            |   py39hecd8cb5_0         206 KB
#     transformers-4.24.0        |   py39hecd8cb5_0         4.7 MB
#     typing-extensions-4.4.0    |   py39hecd8cb5_0           9 KB
#     typing_extensions-4.4.0    |   py39hecd8cb5_0          46 KB
#     tzdata-2022g               |       h04d1e81_0         114 KB
#     urllib3-1.26.14            |   py39hecd8cb5_0         194 KB
#     wheel-0.38.4               |   py39hecd8cb5_0          65 KB
#     xarray-2022.11.0           |   py39hecd8cb5_0         1.6 MB
#     xlwings-0.29.1             |   py39hecd8cb5_0         858 KB
#     xz-5.2.10                  |       h6c40b1e_1         263 KB
#     zipp-3.11.0                |   py39hecd8cb5_0          20 KB
#     zlib-1.2.13                |       h4dc903c_0          96 KB
#     zstandard-0.19.0           |   py39h6c40b1e_0         452 KB
#     ------------------------------------------------------------
#                                            Total:       337.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2023.03-py39_0
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   comm               pkgs/main/osx-64::comm-0.1.2-py39hecd8cb5_0
#   conda-package-str~ pkgs/main/osx-64::conda-package-streaming-0.7.0-py39hecd8cb5_0
#   contourpy          pkgs/main/osx-64::contourpy-1.0.5-py39haf03e11_0
#   docstring-to-mark~ pkgs/main/osx-64::docstring-to-markdown-0.11-py39hecd8cb5_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   flit-core          pkgs/main/osx-64::flit-core-3.8.0-py39hecd8cb5_0
#   huggingface_hub    pkgs/main/osx-64::huggingface_hub-0.10.1-py39hecd8cb5_0
#   imbalanced-learn   pkgs/main/osx-64::imbalanced-learn-0.10.1-py39hecd8cb5_0
#   importlib_resourc~ pkgs/main/noarch::importlib_resources-5.2.0-pyhd3eb1b0_1
#   jaraco.classes     pkgs/main/noarch::jaraco.classes-3.2.1-pyhd3eb1b0_0
#   libopenblas        pkgs/main/osx-64::libopenblas-0.3.21-h54e7dc3_0
#   libprotobuf        pkgs/main/osx-64::libprotobuf-3.20.3-hfff2838_0
#   libuv              pkgs/main/osx-64::libuv-1.44.2-h6c40b1e_0
#   more-itertools     pkgs/main/noarch::more-itertools-8.12.0-pyhd3eb1b0_0
#   nbclassic          pkgs/main/osx-64::nbclassic-0.5.2-py39hecd8cb5_0
#   ninja              pkgs/main/osx-64::ninja-1.10.2-hecd8cb5_5
#   ninja-base         pkgs/main/osx-64::ninja-base-1.10.2-haf03e11_5
#   notebook           pkgs/main/osx-64::notebook-6.5.2-py39hecd8cb5_0
#   notebook-shim      pkgs/main/osx-64::notebook-shim-0.2.2-py39hecd8cb5_0
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pylint-venv        pkgs/main/osx-64::pylint-venv-2.3.0-py39hecd8cb5_0
#   pytoolconfig       pkgs/main/osx-64::pytoolconfig-1.2.5-py39hecd8cb5_1
#   pytorch            pkgs/main/osx-64::pytorch-1.12.1-cpu_py39h64f2f56_1
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   tinycss2           pkgs/main/osx-64::tinycss2-1.2.1-py39hecd8cb5_0
#   tokenizers         pkgs/main/osx-64::tokenizers-0.11.4-py39h8776b5c_1
#   transformers       pkgs/main/osx-64::transformers-4.24.0-py39hecd8cb5_0
#   zstandard          pkgs/main/osx-64::zstandard-0.19.0-py39h6c40b1e_0
#
# The following packages will be UPDATED:
#
#   anaconda-client                     1.11.0-py39hecd8cb5_0 --> 1.11.1-py39hecd8cb5_0
#   arrow              pkgs/main/noarch::arrow-1.2.2-pyhd3eb~ --> pkgs/main/osx-64::arrow-1.2.3-py39hecd8cb5_1
#   astroid                             2.11.7-py39hecd8cb5_0 --> 2.14.2-py39hecd8cb5_0
#   attrs              pkgs/main/noarch::attrs-21.4.0-pyhd3e~ --> pkgs/main/osx-64::attrs-22.1.0-py39hecd8cb5_0
#   babel              pkgs/main/noarch::babel-2.9.1-pyhd3eb~ --> pkgs/main/osx-64::babel-2.11.0-py39hecd8cb5_0
#   blas                                              1.0-mkl --> 1.0-openblas
#   blosc                                   1.21.0-h8346a28_1 --> 1.21.3-hcec6c5f_0
#   c-ares                                  1.18.1-hca72f7f_0 --> 1.19.0-h6c40b1e_0
#   ca-certificates                     2022.07.19-hecd8cb5_0 --> 2023.01.10-hecd8cb5_0
#   certifi                          2022.9.24-py39hecd8cb5_0 --> 2022.12.7-py39hecd8cb5_0
#   cffi                                1.15.1-py39hc55c11b_0 --> 1.15.1-py39h6c40b1e_3
#   colorama                             0.4.5-py39hecd8cb5_0 --> 0.4.6-py39hecd8cb5_0
#   colorcet                             3.0.0-py39hecd8cb5_0 --> 3.0.1-py39hecd8cb5_0
#   conda-package-han~                   1.9.0-py39hca72f7f_0 --> 2.0.2-py39hecd8cb5_0
#   conda-repo-cli                      1.0.20-py39hecd8cb5_0 --> 1.0.27-py39hecd8cb5_0
#   cryptography                        37.0.1-py39hf6deb26_0 --> 39.0.1-py39hf6deb26_0
#   curl                                    7.84.0-hca72f7f_0 --> 7.88.1-h6c40b1e_0
#   cytoolz                             0.11.0-py39h9ed2024_0 --> 0.12.0-py39hca72f7f_0
#   datashader                          0.14.1-py39hecd8cb5_0 --> 0.14.4-py39hecd8cb5_0
#   dill               pkgs/main/noarch::dill-0.3.4-pyhd3eb1~ --> pkgs/main/osx-64::dill-0.3.6-py39hecd8cb5_0
#   filelock           pkgs/main/noarch::filelock-3.6.0-pyhd~ --> pkgs/main/osx-64::filelock-3.9.0-py39hecd8cb5_0
#   flake8             pkgs/main/noarch::flake8-4.0.1-pyhd3e~ --> pkgs/main/osx-64::flake8-6.0.0-py39hecd8cb5_0
#   freetype                                2.11.0-hd8bbffd_0 --> 2.12.1-hd8bbffd_0
#   fsspec                            2022.7.1-py39hecd8cb5_0 --> 2023.3.0-py39hecd8cb5_0
#   future                              0.18.2-py39hecd8cb5_1 --> 0.18.3-py39hecd8cb5_0
#   gensim                               4.1.2-py39he9d5cce_0 --> 4.3.0-py39hcec6c5f_0
#   giflib                                   5.2.1-haf1e3a3_0 --> 5.2.1-h6c40b1e_3
#   glib                                    2.69.1-h8346a28_1 --> 2.69.1-hfff2838_2
#   greenlet                             1.1.1-py39h23ab428_0 --> 2.0.1-py39hcec6c5f_0
#   gst-plugins-base                        1.14.0-h4180768_2 --> 1.14.1-hcec6c5f_1
#   gstreamer                               1.14.0-h0fc69c2_2 --> 1.14.1-h6c40b1e_1
#   idna               pkgs/main/noarch::idna-3.3-pyhd3eb1b0~ --> pkgs/main/osx-64::idna-3.4-py39hecd8cb5_0
#   imagecodecs                      2021.8.26-py39h0f85e6e_1 --> 2021.8.26-py39h8a96914_2
#   imageio                             2.19.3-py39hecd8cb5_0 --> 2.26.0-py39hecd8cb5_0
#   importlib-metadata                  4.11.3-py39hecd8cb5_0 --> 6.0.0-py39hecd8cb5_0
#   importlib_metadata                      4.11.3-hd3eb1b0_0 --> 6.0.0-hd3eb1b0_0
#   intake             pkgs/main/noarch::intake-0.6.5-pyhd3e~ --> pkgs/main/osx-64::intake-0.6.8-py39hecd8cb5_0
#   ipykernel                           6.15.2-py39hecd8cb5_0 --> 6.19.2-py39h01d92e1_0
#   ipython                             7.31.1-py39hecd8cb5_1 --> 8.10.0-py39hecd8cb5_0
#   joblib             pkgs/main/noarch::joblib-1.1.0-pyhd3e~ --> pkgs/main/osx-64::joblib-1.1.1-py39hecd8cb5_0
#   jpeg                                        9e-hca72f7f_0 --> 9e-h6c40b1e_1
#   jsonschema                          4.16.0-py39hecd8cb5_0 --> 4.17.3-py39hecd8cb5_0
#   jupyter_client                       7.3.4-py39hecd8cb5_0 --> 7.4.9-py39hecd8cb5_0
#   jupyter_console    pkgs/main/noarch::jupyter_console-6.4~ --> pkgs/main/osx-64::jupyter_console-6.6.2-py39hecd8cb5_0
#   jupyter_core                        4.11.1-py39hecd8cb5_0 --> 5.2.0-py39hecd8cb5_0
#   jupyter_server                      1.18.1-py39hecd8cb5_0 --> 1.23.4-py39hecd8cb5_0
#   jupyterlab_widgets pkgs/main/noarch::jupyterlab_widgets-~ --> pkgs/main/osx-64::jupyterlab_widgets-3.0.5-py39hecd8cb5_0
#   keyring                             23.4.0-py39hecd8cb5_0 --> 23.13.1-py39hecd8cb5_0
#   kiwisolver                           1.4.2-py39he9d5cce_0 --> 1.4.4-py39hcec6c5f_0
#   krb5                                    1.19.2-hcd88c3b_0 --> 1.19.4-hdba6334_0
#   libarchive                               3.6.1-he336d3b_0 --> 3.6.2-h65c5294_0
#   libcurl                                 7.84.0-h6dfd666_0 --> 7.88.1-ha585b31_0
#   libdeflate                                 1.8-h9ed2024_5 --> 1.17-hb664fd8_0
#   libedit                           3.1.20210910-hca72f7f_0 --> 3.1.20221030-h6c40b1e_0
#   libffi                                     3.3-hb1e8313_2 --> 3.4.2-hecd8cb5_6
#   libgfortran                      5.0.0-11_2_0_h246ff09_26 --> 5.0.0-11_3_0_hecd8cb5_28
#   libgfortran5                           11.2.0-h246ff09_26 --> 11.3.0-h9dfd629_28
#   liblief                                 0.11.5-he9d5cce_1 --> 0.12.3-hcec6c5f_0
#   libllvm11                               11.1.0-h46f1229_5 --> 11.1.0-h46f1229_6
#   libllvm14                               14.0.6-he552d86_0 --> 14.0.6-h91fad77_1
#   libpng                                  1.6.37-ha441bb4_0 --> 1.6.39-h6c40b1e_0
#   libtiff                                  4.4.0-h2ef1027_0 --> 4.5.0-hcec6c5f_2
#   libwebp                                  1.2.2-h56c3ce4_0 --> 1.2.4-hf6ce154_1
#   libwebp-base                             1.2.2-hca72f7f_0 --> 1.2.4-h6c40b1e_1
#   llvmlite                            0.38.0-py39h8346a28_0 --> 0.39.1-py39h8346a28_0
#   lz4-c                                    1.9.3-h23ab428_1 --> 1.9.4-hcec6c5f_0
#   markdown                             3.3.4-py39hecd8cb5_0 --> 3.4.1-py39hecd8cb5_0
#   matplotlib                           3.5.2-py39hecd8cb5_0 --> 3.7.1-py39hecd8cb5_0
#   matplotlib-base                      3.5.2-py39hfb0c5b7_0 --> 3.7.1-py39hda11e5a_0
#   nbformat                             5.5.0-py39hecd8cb5_0 --> 5.7.0-py39hecd8cb5_0
#   ncurses                                    6.3-hca72f7f_3 --> 6.4-hcec6c5f_0
#   nest-asyncio                         1.5.5-py39hecd8cb5_0 --> 1.5.6-py39hecd8cb5_0
#   networkx                             2.8.4-py39hecd8cb5_0 --> 2.8.4-py39hecd8cb5_1
#   numba                               0.55.1-py39hae1ba45_0 --> 0.56.4-py39h07fba90_0
#   numexpr                              2.8.3-py39h2e5f0a9_0 --> 2.8.4-py39h57a7bef_0
#   numpy                               1.21.5-py39h2e5f0a9_3 --> 1.23.5-py39h57a7bef_0
#   numpy-base                          1.21.5-py39h3b1a694_3 --> 1.23.5-py39hc93c6d9_0
#   numpydoc                             1.4.0-py39hecd8cb5_0 --> 1.5.0-py39hecd8cb5_0
#   openssl                                 1.1.1q-hca72f7f_0 --> 1.1.1t-hca72f7f_0
#   packaging          pkgs/main/noarch::packaging-21.3-pyhd~ --> pkgs/main/osx-64::packaging-23.0-py39hecd8cb5_0
#   panel                               0.13.1-py39hecd8cb5_0 --> 0.14.3-py39hecd8cb5_0
#   param              pkgs/main/noarch::param-1.12.0-pyhd3e~ --> pkgs/main/osx-64::param-1.12.3-py39hecd8cb5_0
#   pathspec                             0.9.0-py39hecd8cb5_0 --> 0.10.3-py39hecd8cb5_0
#   patsy                                0.5.2-py39hecd8cb5_1 --> 0.5.3-py39hecd8cb5_0
#   pillow                               9.2.0-py39hde71d04_1 --> 9.4.0-py39hcec6c5f_0
#   pip                                 22.2.2-py39hecd8cb5_0 --> 23.0.1-py39hecd8cb5_0
#   pkginfo            pkgs/main/noarch::pkginfo-1.8.2-pyhd3~ --> pkgs/main/osx-64::pkginfo-1.9.6-py39hecd8cb5_0
#   prompt-toolkit     pkgs/main/noarch::prompt-toolkit-3.0.~ --> pkgs/main/osx-64::prompt-toolkit-3.0.36-py39hecd8cb5_0
#   prompt_toolkit                          3.0.20-hd3eb1b0_0 --> 3.0.36-hd3eb1b0_0
#   py-lief                             0.11.5-py39he9d5cce_1 --> 0.12.3-py39hcec6c5f_0
#   pycodestyle        pkgs/main/noarch::pycodestyle-2.8.0-p~ --> pkgs/main/osx-64::pycodestyle-2.10.0-py39hecd8cb5_0
#   pycosat                              0.6.3-py39h9ed2024_0 --> 0.6.4-py39hca72f7f_0
#   pyct                                 0.4.8-py39hecd8cb5_1 --> 0.5.0-py39hecd8cb5_0
#   pycurl                              7.45.1-py39h0a4fc7d_0 --> 7.45.2-py39hdb2fb19_0
#   pydocstyle         pkgs/main/noarch::pydocstyle-6.1.1-py~ --> pkgs/main/osx-64::pydocstyle-6.3.0-py39hecd8cb5_0
#   pyflakes           pkgs/main/noarch::pyflakes-2.4.0-pyhd~ --> pkgs/main/osx-64::pyflakes-3.0.1-py39hecd8cb5_0
#   pylint                              2.14.5-py39hecd8cb5_0 --> 2.16.2-py39hecd8cb5_0
#   pyobjc-core                            8.5-py39hc55c11b_0 --> 9.0-py39h9205ec4_1
#   pyobjc-framework-~                     8.5-py39hca72f7f_0 --> 9.0-py39h9205ec4_0
#   pyobjc-framework-~                     8.5-py39hca72f7f_0 --> 9.0-py39h46256e1_0
#   pyobjc-framework-~                     8.5-py39hecd8cb5_0 --> 9.0-py39hecd8cb5_0
#   pyopenssl          pkgs/main/noarch::pyopenssl-22.0.0-py~ --> pkgs/main/osx-64::pyopenssl-23.0.0-py39hecd8cb5_0
#   pyproj              anaconda::pyproj-3.3.0-py39h823a480_0 --> pkgs/main::pyproj-3.4.1-py39hf797ea4_0
#   pytables                             3.6.1-py39h648f197_1 --> 3.7.0-py39h59775c6_1
#   python                                  3.9.13-hdfd78df_1 --> 3.9.16-h218abb5_2
#   python-lsp-server                    1.5.0-py39hecd8cb5_0 --> 1.7.1-py39hecd8cb5_0
#   python-snappy                        0.6.0-py39h23ab428_3 --> 0.6.1-py39hcec6c5f_0
#   pytz                                2022.1-py39hecd8cb5_0 --> 2022.7-py39hecd8cb5_0
#   pywavelets                           1.3.0-py39hca72f7f_0 --> 1.4.1-py39h6c40b1e_0
#   qstylizer          pkgs/main/noarch::qstylizer-0.1.10-py~ --> pkgs/main/osx-64::qstylizer-0.2.2-py39hecd8cb5_0
#   qtawesome          pkgs/main/noarch::qtawesome-1.0.3-pyh~ --> pkgs/main/osx-64::qtawesome-1.2.2-py39hecd8cb5_0
#   qtconsole                            5.3.2-py39hecd8cb5_0 --> 5.4.0-py39hecd8cb5_0
#   readline                                 8.1.2-hca72f7f_1 --> 8.2-hca72f7f_0
#   requests                            2.28.1-py39hecd8cb5_0 --> 2.28.1-py39hecd8cb5_1
#   rope               pkgs/main/noarch::rope-0.22.0-pyhd3eb~ --> pkgs/main/osx-64::rope-1.7.0-py39hecd8cb5_0
#   rtree                                0.9.7-py39hecd8cb5_1 --> 1.0.1-py39hecd8cb5_0
#   scikit-image                        0.19.2-py39hae1ba45_0 --> 0.19.3-py39hcec6c5f_1
#   scikit-learn                         1.0.2-py39hae1ba45_1 --> 1.2.1-py39hcec6c5f_0
#   scipy                                1.9.1-py39h3d31255_0 --> 1.10.0-py39h9034365_1
#   scrapy                               2.6.2-py39hecd8cb5_0 --> 2.8.0-py39hecd8cb5_0
#   seaborn            pkgs/main/noarch::seaborn-0.11.2-pyhd~ --> pkgs/main/osx-64::seaborn-0.12.2-py39hecd8cb5_0
#   setuptools                          63.4.1-py39hecd8cb5_0 --> 65.6.3-py39hecd8cb5_0
#   soupsieve          pkgs/main/noarch::soupsieve-2.3.1-pyh~ --> pkgs/main/osx-64::soupsieve-2.3.2.post1-py39hecd8cb5_0
#   spyder                               5.3.3-py39hecd8cb5_0 --> 5.4.2-py39hecd8cb5_0
#   spyder-kernels                       2.3.3-py39hecd8cb5_0 --> 2.4.2-py39hecd8cb5_0
#   sqlite                                  3.39.3-h707629a_0 --> 3.41.1-h6c40b1e_0
#   statsmodels                         0.13.2-py39hca72f7f_0 --> 0.13.5-py39hacda100_1
#   sympy                               1.10.1-py39hecd8cb5_0 --> 1.11.1-py39hecd8cb5_0
#   tbb                                   2021.6.0-haf03e11_0 --> 2021.7.0-ha357a0b_0
#   tbb4py                            2021.6.0-py39haf03e11_0 --> 2021.7.0-py39ha357a0b_0
#   terminado                           0.13.1-py39hecd8cb5_0 --> 0.17.1-py39hecd8cb5_0
#   toolz              pkgs/main/noarch::toolz-0.11.2-pyhd3e~ --> pkgs/main/osx-64::toolz-0.12.0-py39hecd8cb5_0
#   tornado                                6.1-py39h9ed2024_0 --> 6.2-py39hca72f7f_0
#   traitlets          pkgs/main/noarch::traitlets-5.1.1-pyh~ --> pkgs/main/osx-64::traitlets-5.7.1-py39hecd8cb5_0
#   typing-extensions                    4.3.0-py39hecd8cb5_0 --> 4.4.0-py39hecd8cb5_0
#   typing_extensions                    4.3.0-py39hecd8cb5_0 --> 4.4.0-py39hecd8cb5_0
#   tzdata                                   2022c-h04d1e81_0 --> 2022g-h04d1e81_0
#   urllib3                            1.26.11-py39hecd8cb5_0 --> 1.26.14-py39hecd8cb5_0
#   wheel              pkgs/main/noarch::wheel-0.37.1-pyhd3e~ --> pkgs/main/osx-64::wheel-0.38.4-py39hecd8cb5_0
#   xarray             pkgs/main/noarch::xarray-0.20.1-pyhd3~ --> pkgs/main/osx-64::xarray-2022.11.0-py39hecd8cb5_0
#   xlwings                            0.27.15-py39hecd8cb5_0 --> 0.29.1-py39hecd8cb5_0
#   xz                                       5.2.6-hca72f7f_0 --> 5.2.10-h6c40b1e_1
#   zipp                                 3.8.0-py39hecd8cb5_0 --> 3.11.0-py39hecd8cb5_0
#   zlib                                    1.2.12-h4dc903c_3 --> 1.2.13-h4dc903c_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   dask               pkgs/main/osx-64::dask-2022.7.0-py39h~ --> pkgs/main/noarch::dask-2022.2.1-pyhd3eb1b0_0
#   dask-core          pkgs/main/osx-64::dask-core-2022.7.0-~ --> pkgs/main/noarch::dask-core-2022.2.1-pyhd3eb1b0_0
#   distributed        pkgs/main/osx-64::distributed-2022.7.~ --> pkgs/main/noarch::distributed-2022.2.1-pyhd3eb1b0_0
#   geos                                             anaconda --> pkgs/main
#   proj                                             anaconda --> pkgs/main
#   pyshp                                            anaconda --> pkgs/main
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2022.10-py39_0 --> custom-py39_1
#   pyyaml                                 6.0-py39hca72f7f_1 --> 6.0-py39h6c40b1e_1
#
#
#
# Downloading and Extracting Packages
# pyyaml-6.0           | 172 KB    |                                       |   0%
# pillow-9.4.0         | 691 KB    |                                       |   0%
#
# readline-8.2         | 328 KB    |                                       |   0%
#
#
# attrs-22.1.0         | 84 KB     |                                       |   0%
#
#
#
# pycodestyle-2.10.0   | 69 KB     |                                       |   0%
#
#
#
#
# pyshp-2.1.3          | 37 KB     |                                       |   0%
#
#
#
#
#
# jupyterlab_widgets-3 | 180 KB    |                                       |   0%
#
#
#
#
#
#
# contourpy-1.0.5      | 205 KB    |                                       |   0%
#
#
#
#
#
#
#
# greenlet-2.0.1       | 184 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# jsonschema-4.17.3    | 140 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pooch-1.4.0          | 41 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 96 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 96 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.6.2     | 777 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# notebook-shim-0.2.2  | 23 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.56.4         | 4.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycurl-7.45.2        | 130 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spyder-kernels-2.4.2 | 152 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xarray-2022.11.0     | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.5.6   | 16 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    |                                       |   0%
#  ... (more hidden) ...
# pillow-9.4.0         | 691 KB    | 8                                     |   2%
#
# readline-8.2         | 328 KB    | #8                                    |   5%
#
#
#
# pycodestyle-2.10.0   | 69 KB     | ########5                             |  23%
#
#
# pyyaml-6.0           | 172 KB    | ###4                                  |   9%
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ###############9                      |  43%
#
#
#
#
#
#
# contourpy-1.0.5      | 205 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
# greenlet-2.0.1       | 184 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
# jsonschema-4.17.3    | 140 KB    | ####2                                 |  11%
#
#
#
#
#
# jupyterlab_widgets-3 | 180 KB    | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##############4                       |  39%
#
#
#
# pycodestyle-2.10.0   | 69 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# notebook-shim-0.2.2  | 23 KB     | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 96 KB     | ######1                               |  17%
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.6.2     | 777 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.56.4         | 4.0 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spyder-kernels-2.4.2 | 152 KB    | ###8                                  |  11%
#
#
# attrs-22.1.0         | 84 KB     | ##################################### | 100%
#
#
# attrs-22.1.0         | 84 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 172 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pyyaml-6.0           | 172 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycurl-7.45.2        | 130 KB    | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | 4                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.56.4         | 4.0 MB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.5.6   | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ####1                                 |  11%
#
# readline-8.2         | 328 KB    | ##################################### | 100%
#
# readline-8.2         | 328 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xarray-2022.11.0     | 1.6 MB    | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pillow-9.4.0         | 691 KB    | ##################################### | 100%
# pillow-9.4.0         | 691 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ##################################### | 100%
#
#
#
#
# pyshp-2.1.3          | 37 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
# jsonschema-4.17.3    | 140 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# jsonschema-4.17.3    | 140 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# greenlet-2.0.1       | 184 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# greenlet-2.0.1       | 184 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
#
#
#
#
#
# jupyterlab_widgets-3 | 180 KB    | ##################################### | 100%
#
#
#
#
#
# jupyterlab_widgets-3 | 180 KB    | ##################################### | 100%
#
#
#
#
#
#
# contourpy-1.0.5      | 205 KB    | ##################################### | 100%
#
#
#
#
#
#
# contourpy-1.0.5      | 205 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# notebook-shim-0.2.2  | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# notebook-shim-0.2.2  | 23 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 96 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 96 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.6.2     | 777 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libarchive-3.6.2     | 777 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spyder-kernels-2.4.2 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# spyder-kernels-2.4.2 | 152 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# stack_data-0.2.0     | 22 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 96 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 96 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycurl-7.45.2        | 130 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pycurl-7.45.2        | 130 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nest-asyncio-1.5.6   | 16 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numba-0.56.4         | 4.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
# libgfortran-5.0.0    | 142 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xarray-2022.11.0     | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update ipydatawidgets
# Out:
# Note: you may need to restart the kernel to use updated packages.
